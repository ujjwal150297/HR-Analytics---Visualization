# %%
# Import libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset

data=pd.read_csv("employe.csv")

data
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
print(data.to_string() )  # To display the full data in output box
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  timeSpent.company  workAccident  left  promotionInLast5years         dept  salary
# 0                   0.38            0.53                 2              157                  3             0     1                      0        sales     low
# 1                   0.80            0.86                 5              262                  6             0     1                      0        sales  medium
# 2                   0.11            0.88                 7              272                  4             0     1                      0        sales  medium
# 3                   0.37            0.52                 2              159                  3             0     1                      0        sales     low
# 4                   0.41            0.50                 2              153                  3             0     1                      0        sales     low
# ...

# %%
# I want to display top 10 records

data.head(10)
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
# 5               0.10            0.77                 6              247
# 6               0.92            0.85                 5              259
# 7               0.42            0.53                 2              142
# 8               0.45            0.54                 2              135
# 9               0.11            0.81                 6              305
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# ...

# %%
# I want to display bottom 15 records

data.tail(15)
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14984               0.62            0.71                 4              268
# 14985               0.95            0.84                 3              270
# 14986               0.76            1.00                 4              220
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14989               0.69            0.70                 3              212
# 14990               0.73            0.52                 3              274
# 14991               0.85            0.53                 3              250
# 14992               0.30            0.88                 5              245
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
# ...

# %%
data.shape # To check the no of rows and no of columns of your data
# Out:
# (14999, 10)

# %%
data.info()  # To check information about your data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      14999 non-null  float64
#  1   lastEvaluation         14999 non-null  float64
#  2   numberOfProjects       14999 non-null  int64
#  3   avgMonthlyHours        14999 non-null  int64
#  4   timeSpent.company      14999 non-null  int64
#  5   workAccident           14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotionInLast5years  14999 non-null  int64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
# Null means NO VALUE
# non-Null means VALUE

# %%
# Clean my data  - DATA CLEANING PART/STEP
'''
1st check for null values
2nd check for duplicate data
'''

# %%
data.isnull()

# False means NO NULL VALUE
# True means NULL VALUE
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                  False           False             False            False
# 1                  False           False             False            False
# 2                  False           False             False            False
# 3                  False           False             False            False
# 4                  False           False             False            False
# ...                  ...             ...               ...              ...
# 14994              False           False             False            False
# 14995              False           False             False            False
# 14996              False           False             False            False
# 14997              False           False             False            False
# 14998              False           False             False            False
#
# ...

# %%
data.isnull().sum()  # total sum of null value for each and every columns
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
data.duplicated().sum()  # retutn you the no of duplicate record in your data
# Out:
# 3008

# %%
14999 - 3008
# Out:
# 11991

# %%
# see the duplicate records

data[data.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
# We need to remove this duplicate data from original data

# 14999 rows
# 3008 are dupliacates from it

data=data.drop_duplicates()

# %%
data.shape
# Out:
# (11991, 10)

# %%
# WE ARE HAVING CLEAN DATA NOW

# %%
#data = pd.read_csv(r"C:\Users\Ananda krishnan\Downloads\employe-hr analytics")
 # use r to avoid the UNICODE error while importing file by path

# %%
list1=[ "dept" ,"salary" , "numberOfProjects" ,"workAccident" ,"promotionInLast5years" ,"timeSpent.company"]
# Important columns

fig=plt.subplots(figsize=(20,25))   # figure size

for p,q in enumerate(list1):
  plt.subplot( 3,2 ,p+1 )
  sns.countplot(x=q , data=data,hue="left")
  #plt.text()
  plt.xticks(rotation=90)   # rotate the values on x axis by 90 degree to solve the issue of overlapping
  plt.plot()  # just to draw plot in output box
# Out:
# <ipython-input-24-18aaf0ff22de>:7: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot( 3,2 ,p+1 )

# %%
list1=[ "dept" ,"salary" , "numberOfProjects" ,"workAccident" ,"promotionInLast5years" ,"timeSpent.company"]
# Important columns
for p,q in enumerate(list1):
  print( 3,2 ,p+1  , q ,"vs left")
# Out:
# 3 2 1 dept vs left
# 3 2 2 salary vs left
# 3 2 3 numberOfProjects vs left
# 3 2 4 workAccident vs left
# 3 2 5 promotionInLast5years vs left
# 3 2 6 timeSpent.company vs left

# %%
list1=["Apple","Banana","Watermelon","Cheery"]
for i in list1:
  print(i)
# Out:
# Apple
# Banana
# Watermelon
# Cheery

# %%
list1=["Apple","Banana","Watermelon","Cheery"]
for i , j in enumerate(list1):
  print(i,j)
# Out:
# 0 Apple
# 1 Banana
# 2 Watermelon
# 3 Cheery

# %%
# code check
list1 = ['dept', 'salary', 'timeSpent.company', 'promotionInLast5years', 'numberOfProjects', 'workAccident']
fig=plt.subplots(figsize=(20,25))
for p, q in enumerate (list1):
    plt.subplot(3,2,p+1)
    sns.countplot(x=q, data=data, hue='left')
    plt.xticks(rotation=90)
    plt.plot()
# Out:
# <ipython-input-29-9271adfc12e4>:5: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,p+1)

# %%
# list1=["dept" ,"salary" , "numberOfprojects" , "workAccident","promotionInLast5years","timeSpent.company"]
# fig=plt.subplots(figsize=(20,25))
# for p,q in enumerate(list1):
#     plt.subplot(3,2, p+1)
#     sns.countplot(x=q,data=data,hue="left")
#     plt.xticks(rotation=90)
#     plt.plot()


list1 = ['dept', 'salary', 'timeSpent.company', 'promotionInLast5years', 'numberOfProjects', 'workAccident']
# fig=plt.subplots(figsize=(20,25))
# for p, q in enumerate(list1):
#     plt.subplot(3,2, p+1)
#     sns.countplot(x=q, data=data, hue='left')
#     plt.xticks(rotation=90)
#     plt.plot()


fig=plt.subplots(figsize=(20,25))
for p,q in enumerate(list1):
  plt.subplot(3,2,p+1)
  sns.countplot(x=q,data=data,hue="left")
  plt.xticks(rotation=90)
  plt.plot()
# Out:
# <ipython-input-33-e5fa73efd889>:21: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,p+1)

# %%
# code check
list1=["dept","salary","numberOfProjects","workAccident","promotionInLast5years","timeSpent.company"]

fig = plt.subplots(figsize=(20,25))  # fig size
for p,q in enumerate(list1):
  plt.subplot(3,2,p+1)
  sns.countplot(x=q,data=data,hue="left")  # hue is used for compare the left columns
  plt.xticks(rotation=90) # just rotate the values on x axis by 90 degree to solve the issue of overlapping
  plt.plot()
# Out:
# <ipython-input-30-07659d2750d0>:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(3,2,p+1)

# %%
# CONCLUSION
'''
1- Mostly people are leaving from  Sales , Technical , Support

2- Most of the people who left the company were getting LOW salary


3-Work is not properly distributed some are getting less chance to showcase their skill and some are getting so much of work load
All the employees who wre handling 7 project alreadt left the company.

4- Work accident is not having any direct relation with left column

5- The people who got 0 promotion left the company so provide the promotion to deserving one's

6- Frehser are not leaving , experienced one's are not leaving , The people who want to c=explore some new thung only they are leaving

Employees working for many years are not leaving loyalty have an impact

'''
